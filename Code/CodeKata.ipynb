# %% [markdown]
# # Unsolved

# %%
# Question : 734
## You are given with a number series. Write a program to print the first N numebrs of the number series.
## 1 2 4 8 16 32 64 128...

num = int(input())
index = 1 
result = 1

while index <= num: 
    print(result,end=" ")
    result = result*2 
    index = index + 1
# Out:
# 1 2 4 8 16

# %%
# Question : 734

def number_series(num):
    index = 1 
    result = 1

    while index <= int(num): 
        print(result,end=" ")
        result = result*2 
        index = index + 1

num=input()
number_series(num)
# Out:
# 1 2 4 8 16 32 64 128 256 512 1024 2048 4096 8192 16384 32768 65536 131072 262144 524288 1048576 2097152 4194304 8388608 16777216 33554432 67108864 134217728 268435456 536870912 1073741824 2147483648 4294967296 8589934592 17179869184 34359738368 68719476736 137438953472 274877906944 549755813888 1099511627776 2199023255552 4398046511104 8796093022208 17592186044416 35184372088832 70368744177664 140737488355328 281474976710656 562949953421312 1125899906842624 2251799813685248 4503599627370496 9007199254740992 18014398509481984 36028797018963968 72057594037927936 144115188075855872 288230376151711744 576460752303423488 1152921504606846976 2305843009213693952 4611686018427387904 9223372036854775808 18446744073709551616 36893488147419103232 73786976294838206464 147573952589676412928 295147905179352825856 590295810358705651712 1180591620717411303424 2361183241434822606848 4722366482869645213696 9444732965739290427392 18889465931478580854784 37778931862957161709568 75557863725914323419136 1
# ...

# %%
#Question:765
input_value=2
meter_value=1000*input_value
cm_value=1000*100*input_value

print(meter_value )
print(cm_value)
print(f"{meter_value}{cm_value}")
# Out:
# 2000
# 200000
# 2000200000

# %%
#Question:764
import numpy as np

a=20

area = 0.25 * np.sqrt(3) * a**2

area
# Out:
# np.float64(173.20508075688772)

# %%
#Question:764
import math
 
num = input()
num = float(num)
area = round((1/4)* math.sqrt(3) * (num ** 2), 2)
print(area)
# Out:
# 0.11

# %%
#Question:770
num1 = input()
num2 = input()
num3 = input()

if num3 > num2 and num3 > num1:
    print(num3)
elif num2 > num1 and num2 > num3:
    print(num2)
else:
    print(num1)
# Out:
# 3

# %%
#Question:770
value = input()
num = round(float(value))
print(num)
if num == 0:
    print("Zero")
elif num % 2 == 0 :
    print("Even")
else:
    print("odd")
# Out:
# 1
# odd
