# %% [markdown]
# # 19-Jan-2026

# %%
import numpy as np

a = np.random.rand(100)
b = np.random.rand(100)

np.corrcoef(a,b)
# Out:
# array([[1.        , 0.06050458],
#        [0.06050458, 1.        ]])
