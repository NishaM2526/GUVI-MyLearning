# %% [markdown]
# # 10 Feb 2026

# %%
# !pip3 install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/17.0 MB 15.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 5.0/17.0 MB 16.2 MB/s eta 0:00:01
#    -------------------- ------------------- 8.7/17.0 MB 16.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 12.1/17.0 MB 16.4 MB/s eta 0:00:01
#    ------------------------------------- -- 15.7/17.0 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------- 17.0/17.0 MB 15.7 MB/s  0:00:01
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
import mysql.connector
connection = mysql.connector.connect(
    user="root",
    host="localhost",
    password="Nisha@2506"
)

cursor = connection.cursor()
cursor

# %%
query="create database B143"
cursor.execute(query)

# %%
query="show databases"
cursor.execute(query)
for db in cursor:
    print(db)
# Out:
# ('b143',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sql_hr',)
# ('sql_inventory',)
# ('sql_invoicing',)
# ('sql_store',)
# ('sys',)
# ('world',)

# %%
query="use b143"
cursor.execute(query)

# %%
query = "create table Learners(user_name varchar(60),weight float, height float,email varchar(100))"
cursor.execute(query)

# %%
query = "show tables"
cursor.execute(query)
for tb in cursor:
    print(tb)
# Out:
# ('learners',)

# %%
query = "insert into Learners(user_name,weight,height,email) values('Nisha',65.0,5.5,'nisha.m@gmail.com')"

cursor.execute(query)

# %%
query = "insert into learners values ('Ragesh',68.8,6.2,'ragesh.n@gmail.com')"
cursor.execute(query)

# %%
query = "insert into learners values (%s,%s,%s,%s)"
data=('Yathvika',18,3.8,'yathvika.r@gmail.com')

cursor.execute(query,data)

# %%
query = "insert into learners values (%s,%s,%s,%s)"
data=[
    ('Sharvesh',9.0,2.0,'sharvesh.r@gmail.com'),
    ('Nirmal',70.8,6.0,'nirmal.m@gmail.com'),
    ('Mithra',34.0,4.2,'mithra.n@gmail.com'),
    ('Nikitha',48.9,5.3,'nikitha.m@gmail.com'),
]

cursor.executemany(query,data)

# %%
query = "select * from learners"
cursor.execute(query)

for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com')
# ('Ragesh', 68.8, 6.2, 'ragesh.n@gmail.com')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com')
# ('Nirmal', 70.8, 6.0, 'nirmal.m@gmail.com')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com')

# %%
query = "select user_name,weight from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0)
# ('Ragesh', 68.8)
# ('Yathvika', 18.0)
# ('Sharvesh', 9.0)
# ('Nirmal', 70.8)
# ('Mithra', 34.0)
# ('Nikitha', 48.9)

# %%
query = "select user_name,email from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 'nisha.m@gmail.com')
# ('Ragesh', 'ragesh.n@gmail.com')
# ('Yathvika', 'yathvika.r@gmail.com')
# ('Sharvesh', 'sharvesh.r@gmail.com')
# ('Nirmal', 'nirmal.m@gmail.com')
# ('Mithra', 'mithra.n@gmail.com')
# ('Nikitha', 'nikitha.m@gmail.com')

# %%
query = "select * from learners where weight>=65"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com')
# ('Ragesh', 68.8, 6.2, 'ragesh.n@gmail.com')
# ('Nirmal', 70.8, 6.0, 'nirmal.m@gmail.com')

# %%
# create a table named staff having following columns
#1. Name varchar(100)
#.Department. varchar(100)
#salary float
# experience int

query = "create table staff (name varchar(100),department varchar(100),salary float, experience int)"
cursor.execute(query)

# %%
query = "show tables"
cursor.execute(query)

for tb in cursor:
    print(tb)
# Out:
# ('learners',)
# ('staff',)

# %%
query="insert into staff values(%s,%s,%s,%s)"

data=[
    ("Nisha","DS",10,7)
]
cursor.executemany(query,data)

# %%
query="select * from staff"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 'DS', 10.0, 7)

# %%
query="select * from learners limit 3"
cursor.execute(query)

for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com')
# ('Ragesh', 68.8, 6.2, 'ragesh.n@gmail.com')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com')

# %%
query="select * from learners order by user_name"
cursor.execute(query)

for data in cursor:
    print(data)
# Out:
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com')
# ('Nirmal', 70.8, 6.0, 'nirmal.m@gmail.com')
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com')
# ('Ragesh', 68.8, 6.2, 'ragesh.n@gmail.com')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com')

# %%
query="select * from learners order by user_name desc"
cursor.execute(query)

for data in cursor:
    print(data)
# Out:
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com')
# ('Ragesh', 68.8, 6.2, 'ragesh.n@gmail.com')
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com')
# ('Nirmal', 70.8, 6.0, 'nirmal.m@gmail.com')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com')

# %%
query="update learners set user_name='Ragesh N' where user_name='Ragesh'"
cursor.execute(query)
connection.commit()

query="select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com')
# ('Nirmal', 70.8, 6.0, 'nirmal.m@gmail.com')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com')

# %%
query="delete from learners where user_name='Nirmal'"
cursor.execute(query)
connection.commit()

query="select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com')

# %% [markdown]
# # 11 Feb 2026

# %%
import mysql.connector
connection = mysql.connector.connect(
    user="root",
    host="localhost",
    password="Nisha@2506",
    database="B143"
)

cursor = connection.cursor()
cursor

# %%
query = "truncate staff"
cursor.execute(query)

# %%
query = "drop table staff"
cursor.execute(query)

# %%
query = "describe learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('user_name', 'varchar(60)', 'YES', '', None, '')
# ('weight', 'float', 'YES', '', None, '')
# ('height', 'float', 'YES', '', None, '')
# ('email', 'varchar(100)', 'YES', '', None, '')

# %%
query = "alter table learners add course varchar(20)"
cursor.execute(query)

# %%
query = "describe learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('user_name', 'varchar(60)', 'YES', '', None, '')
# ('weight', 'float', 'YES', '', None, '')
# ('height', 'float', 'YES', '', None, '')
# ('email', 'varchar(100)', 'YES', '', None, '')
# ('course', 'varchar(20)', 'YES', '', None, '')

# %%
query = "alter table learners modify course int"
cursor.execute(query)
query = "describe learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('user_name', 'varchar(60)', 'YES', '', None, '')
# ('weight', 'float', 'YES', '', None, '')
# ('height', 'float', 'YES', '', None, '')
# ('email', 'varchar(100)', 'YES', '', None, '')
# ('course', 'int', 'YES', '', None, '')

# %%
query = "alter table learners modify user_name int"
cursor.execute(query)
query = "describe learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\nisha\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Incorrect integer value: 'Nisha' for column 'user_name' at row 1
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[8], line 2
# ...

# %% [markdown]
# # DDL --> Data definition language (create,drop,truncate,alter)
# # DML --> Data manupulation language (select, insert,update,delete)

# %%
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'AIML', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'AIML', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', 'trichy')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', 'trichy')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', 'trichy')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'AIML', 'chennai')

# %%
query = "alter table learners modify course varchar(20)"
cursor.execute(query)
query = "describe learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('user_name', 'varchar(60)', 'YES', '', None, '')
# ('weight', 'float', 'YES', '', None, '')
# ('height', 'float', 'YES', '', None, '')
# ('email', 'varchar(100)', 'YES', '', None, '')
# ('course', 'varchar(20)', 'YES', '', None, '')
# ('city', 'varchar(20)', 'YES', '', None, '')

# %%
query = "update learners set course='Data Science'"
cursor.execute(query)

# %%
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'Data Science', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'Data Science', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', 'trichy')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', 'trichy')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', 'trichy')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'Data Science', 'chennai')

# %%
query = "alter table learners add city varchar(20)"
cursor.execute(query)
query = "describe learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\nisha\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate column name 'city'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 2
#       1 query = "alter table learners add city varchar(20)"
# ...

# %%
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'Data Science', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'Data Science', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', 'trichy')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', 'trichy')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', 'trichy')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'Data Science', 'chennai')

# %%
query = "update learners set course='AIML' where weight>40"
cursor.execute(query)
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'AIML', None)
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'AIML', None)
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', None)
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', None)
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', None)
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'AIML', None)

# %%
query = "update learners set city='chennai' where weight>40"
cursor.execute(query)
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'AIML', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'AIML', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', None)
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', None)
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', None)
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'AIML', 'chennai')

# %%
query = "update learners set city='trichy' where weight<40"
cursor.execute(query)
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'AIML', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'AIML', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', 'trichy')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', 'trichy')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', 'trichy')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'AIML', 'chennai')

# %%
# 1. select
# 2. where
# 3. groupby
# 4. Having
# 5. orderby

# %%
query = "select city,avg(weight) from learners group by city"
cursor.execute(query)  
for data in cursor:
    print(data)
# Out:
# ('chennai', 60.900001525878906)
# ('trichy', 20.333333333333332)

# %%
query = "select course,avg(weight) from learners group by course having course='AIML'"
cursor.execute(query)  
for data in cursor:
    print(data)
# Out:
# ('AIML', 60.900001525878906)

# %%
query = "select course,avg(weight) from learners group by course order by course"
cursor.execute(query)  
for data in cursor:
    print(data)
# Out:
# ('Data Science', 40.61666742960612)

# %% [markdown]
# Data types:
# 1. Numeric
#     a. Integer
#         * int
#         * smallint
#         * bigint
#     b. Float
#         * float
#         * double
#         * decimal (p,s)
# 2. String char based
#     a. char
#     b. varchar(n)
#     c. text
# 3. Boolean - True/False
# 4. Date time
#     a. date
#     b. Time
#     c. Timestamp
#     d. Datetime
# 5. Binary - store files/images

# %% [markdown]
# Constrain:
# 1. Primary key -> unique column -> cannot have null value, must be unique, only one PK in a table

# %%
query = """create table staff (
                            emp_no int primary key,
                            email varchar(100) unique,
                            phone_no bigint not null,
                            age int check(age>=18),
                            is_married varchar(20) default 'not yet'
                            )"""
cursor.execute(query)
query="describe staff"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('emp_no', 'int', 'NO', 'PRI', None, '')
# ('email', 'varchar(100)', 'YES', 'UNI', None, '')
# ('phone_no', 'bigint', 'NO', '', None, '')
# ('age', 'int', 'YES', '', None, '')
# ('is_married', 'varchar(20)', 'YES', '', 'not yet', '')

# %%
connection.commit()

# %%
query="create user 'nisha'@'localhost' identified by 'nisha123'"
cursor.execute(query)
connection.commit()

# %%
query = """ 
            Grant select on b143.*
            to 'nisha'@'localhost'
        """
cursor.execute(query)
connection.commit()

# %%
query="show grants for 'nisha'@'localhost'"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('GRANT USAGE ON *.* TO `nisha`@`localhost`',)
# ('GRANT SELECT ON `b143`.* TO `nisha`@`localhost`',)

# %%
query = """ 
            Grant update on b143.*
            to 'nisha'@'localhost'
        """
cursor.execute(query)
connection.commit()

# %%
query="show grants for 'nisha'@'localhost'"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('GRANT USAGE ON *.* TO `nisha`@`localhost`',)
# ('GRANT SELECT, UPDATE ON `b143`.* TO `nisha`@`localhost`',)

# %%
query="show grants for 'root'@'localhost'"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('GRANT SELECT, INSERT, UPDATE, DELETE, CREATE, DROP, RELOAD, SHUTDOWN, PROCESS, FILE, REFERENCES, INDEX, ALTER, SHOW DATABASES, SUPER, CREATE TEMPORARY TABLES, LOCK TABLES, EXECUTE, REPLICATION SLAVE, REPLICATION CLIENT, CREATE VIEW, SHOW VIEW, CREATE ROUTINE, ALTER ROUTINE, CREATE USER, EVENT, TRIGGER, CREATE TABLESPACE, CREATE ROLE, DROP ROLE ON *.* TO `root`@`localhost` WITH GRANT OPTION',)
# ...

# %%
query="show grants for 'nisha'@'localhost'"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('GRANT USAGE ON *.* TO `nisha`@`localhost`',)
# ('GRANT SELECT, UPDATE ON `b143`.* TO `nisha`@`localhost`',)

# %%
query ="revoke UPDATE on b143.* from 'nisha'@'localhost'"
cursor.execute(query)
connection.commit()
query = "show grants for 'nisha'@'localhost'"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('GRANT USAGE ON *.* TO `nisha`@`localhost`',)
# ('GRANT SELECT ON `b143`.* TO `nisha`@`localhost`',)

# %%
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'Data Science', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'Data Science', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', 'trichy')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', 'trichy')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', 'trichy')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'Data Science', 'chennai')

# %%
query = "select abs(weight) from learners" #absolute - No negative values
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# (65.0,)
# (68.80000305175781,)
# (18.0,)
# (9.0,)
# (34.0,)
# (48.900001525878906,)

# %%
query = "select height,round(height) from learners" 
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# (5.5, 6.0)
# (6.2, 6.0)
# (3.8, 4.0)
# (2.0, 2.0)
# (4.2, 4.0)
# (5.3, 5.0)

# %%
query = "select height,ceil(height) from learners" 
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# (5.5, 6.0)
# (6.2, 7.0)
# (3.8, 4.0)
# (2.0, 2.0)
# (4.2, 5.0)
# (5.3, 6.0)

# %%
query = "select height,floor(height) from learners" 
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# (5.5, 5.0)
# (6.2, 6.0)
# (3.8, 3.0)
# (2.0, 2.0)
# (4.2, 4.0)
# (5.3, 5.0)

# %%
query = "select height,mod(height,2) from learners" 
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# (5.5, 1.5)
# (6.2, 0.19999980926513672)
# (3.8, 1.7999999523162842)
# (2.0, 0.0)
# (4.2, 0.19999980926513672)
# (5.3, 1.3000001907348633)

# %%
query = "select concat('hello',' ','Learners')"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('hello Learners',)

# %%
query = "select concat(user_name,'|',course) from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha|Data Science',)
# ('Ragesh N|Data Science',)
# ('Yathvika|Data Science',)
# ('Sharvesh|Data Science',)
# ('Mithra|Data Science',)
# ('Nikitha|Data Science',)

# %%
query = "select user_name,length(user_name) from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 5)
# ('Ragesh N', 8)
# ('Yathvika', 8)
# ('Sharvesh', 8)
# ('Mithra', 6)
# ('Nikitha', 7)

# %%
query = "select user_name,length(user_name),upper(user_name),lower(user_name) from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 5, 'NISHA', 'nisha')
# ('Ragesh N', 8, 'RAGESH N', 'ragesh n')
# ('Yathvika', 8, 'YATHVIKA', 'yathvika')
# ('Sharvesh', 8, 'SHARVESH', 'sharvesh')
# ('Mithra', 6, 'MITHRA', 'mithra')
# ('Nikitha', 7, 'NIKITHA', 'nikitha')

# %%
query = "select user_name,length(user_name),substring(user_name,1,3) from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 5, 'Nis')
# ('Ragesh N', 8, 'Rag')
# ('Yathvika', 8, 'Yat')
# ('Sharvesh', 8, 'Sha')
# ('Mithra', 6, 'Mit')
# ('Nikitha', 7, 'Nik')

# %%
query = "select user_name,length(user_name),substring(user_name,1,3),trim(user_name) from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 5, 'Nis', 'Nisha')
# ('Ragesh N', 8, 'Rag', 'Ragesh N')
# ('Yathvika', 8, 'Yat', 'Yathvika')
# ('Sharvesh', 8, 'Sha', 'Sharvesh')
# ('Mithra', 6, 'Mit', 'Mithra')
# ('Nikitha', 7, 'Nik', 'Nikitha')

# %% [markdown]
# # 12 Feb 2026

# %%
import mysql.connector
connection = mysql.connector.connect(
    user="root",
    host="localhost",
    password="Nisha@2506",
    database="B143"
)

cursor = connection.cursor()
cursor

# %%
query ="select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'Data Science', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'Data Science', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', 'trichy')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', 'trichy')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', 'trichy')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'Data Science', 'chennai')

# %%
query = "update learners set course='AIML' where weight>40"
cursor.execute(query)
query = "select * from learners"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nisha', 65.0, 5.5, 'nisha.m@gmail.com', 'AIML', 'chennai')
# ('Ragesh N', 68.8, 6.2, 'ragesh.n@gmail.com', 'AIML', 'chennai')
# ('Yathvika', 18.0, 3.8, 'yathvika.r@gmail.com', 'Data Science', 'trichy')
# ('Sharvesh', 9.0, 2.0, 'sharvesh.r@gmail.com', 'Data Science', 'trichy')
# ('Mithra', 34.0, 4.2, 'mithra.n@gmail.com', 'Data Science', 'trichy')
# ('Nikitha', 48.9, 5.3, 'nikitha.m@gmail.com', 'AIML', 'chennai')

# %%
query = "insert into learners value ('Nisha',65.0,5.5,'nisha.m@gmail.com','Data Science','chennai')"
cursor.execute(query)
for data in cursor:
    print(data)

# %%
query ="""
            select user_name,
            weight,
            RANK() over(order by weight)
            from learners
        """
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Sharvesh', 9.0, 1)
# ('Yathvika', 18.0, 2)
# ('Mithra', 34.0, 3)
# ('Nikitha', 48.9, 4)
# ('Nisha', 65.0, 5)
# ('Nisha', 65.0, 5)
# ('Ragesh N', 68.8, 7)

# %%
query ="""
            select user_name,
            weight,
            DENSE_RANK() over(order by weight)
            from learners
        """
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Sharvesh', 9.0, 1)
# ('Yathvika', 18.0, 2)
# ('Mithra', 34.0, 3)
# ('Nikitha', 48.9, 4)
# ('Nisha', 65.0, 5)
# ('Nisha', 65.0, 5)
# ('Ragesh N', 68.8, 6)

# %%
query ="""
            select user_name,
            weight,
            RANK() over(partition by course order by weight)
            from learners
        """
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Nikitha', 48.9, 1)
# ('Nisha', 65.0, 2)
# ('Ragesh N', 68.8, 3)
# ('Sharvesh', 9.0, 1)
# ('Yathvika', 18.0, 2)
# ('Mithra', 34.0, 3)

# %%
connection.commit()
