# %% [markdown]
# # 14 JAN 2026

# %% [markdown]
# ## Day 1

# %%
print("Have a great day!")
# Out:
# Have a great day!

# %%
print('Have a great day!')
# Out:
# Have a great day!

# %%
user_name = input("Enter your name: ")
print(user_name)
# Out:
# Nisha

# %%
education_level =input("Enter your education:")
print(education_level)
# Out:
# Btech

# %%
user_name = input("Enter your name: ")
print(f"Welcome {user_name} to the DATA SCIENCE class.. All the best" )
# Out:
# Welcome Nisha to the DATA SCIENCE class.. All the best

# %%
user_name = input("Enter your name:")
user_email= input("Enter your email ID:")
print(f"Hi {user_name} please verify your email as {user_email}")
# Out:
# Hi Nisha please verify your email as nisha.m@gmail.com

# %%
user_name = "Yathvika"
user_age = 7
user_height = 3.5
is_married = False
print(f"user name data type: {type(user_name)}")
print(f"user age data type: {type(user_age)}")
print(f"user height data type: {type(user_height)}")
print(f"is married data type: {type(is_married)}")
# Out:
# user name data type: <class 'str'>
# user age data type: <class 'int'>
# user height data type: <class 'float'>
# is married data type: <class 'bool'>

# %%
user_name = input("Enter your name:")
user_age = input("Enter your age:")
user_height = input("Enter your height:")
is_married = input("Enter your marital status (True/False):")
print(f"user name data type: {type(user_name)}")
print(f"user age data type: {type(user_age)}")
print(f"user height data type: {type(user_height)}")
print(f"is married data type: {type(is_married)}")
# Out:
# user name data type: <class 'str'>
# user age data type: <class 'str'>
# user height data type: <class 'str'>
# is married data type: <class 'str'>

# %% [markdown]
# # Type casting

# %%
user_name = input("Enter your name:")
user_age = int(input("Enter your age:"))
user_height = float(input("Enter your height:"))
is_married = bool(input("Enter your marital status (True/False):"))
print(f"user name data type: {type(user_name)}")
print(f"user age data type: {type(user_age)}")
print(f"user height data type: {type(user_height)}")
print(f"is married data type: {type(is_married)}")
# Out:
# user name data type: <class 'str'>
# user age data type: <class 'int'>
# user height data type: <class 'float'>
# is married data type: <class 'bool'>

# %%
user_names = ["Nisha", "Ragesh", "Yathvika"]
print(type(user_names))
print(user_names)
# Out:
# <class 'list'>
# ['Nisha', 'Ragesh', 'Yathvika', 'Nisha']

# %%
user_names.append("Sharvesh")
print(type(user_names))
print(user_names)
# Out:
# <class 'list'>
# ['Nisha', 'Ragesh', 'Yathvika', 'Sharvesh']

# %%
user_names[0]
# Out:
# 'Nisha'

# %%
user_names = {"Nisha","Ragesh","Yathvika","Nisha"}
print(type(user_names))
print(user_names)
# Out:
# <class 'set'>
# {'Yathvika', 'Ragesh', 'Nisha'}

# %%
user_names.append("Anu")
print(type(user_names))
print(user_names)
# Out:
# <class 'list'>
# ['Nisha', 'Ragesh', 'Yathvika', 'Nisha', 'Anu']

# %%
user_names = ("Nisha","Ragesh","Yathvika","Nisha")
print(type(user_names))
print(user_names)
# Out:
# <class 'tuple'>
# ('Nisha', 'Ragesh', 'Yathvika', 'Nisha')

# %%
user_names.append("Anu")
print(type(user_names))
print(user_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 user_names.append("Anu")
#       2 print(type(user_names))
#       3 print(user_names)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
age = 13

if age >= 18:
    print("you are eligible to vote")
else:
    print("you are underage")
# Out:
# you are underage

# %%
scores = [45,87,23,66,55]
updated_scores =[]

for var in scores:
    new_score = var + 5
    updated_scores.append(new_score)

print(f"Old scores : {scores}")
print(f"updated scores :{updated_scores}")
# Out:
# Old scores : [45, 87, 23, 66, 55]
# updated scores :[50, 92, 28, 71, 60]

# %%
# !pip install pandas

# %%
import pandas as pd
path = r"C:\Users\nisha\OneDrive\Desktop\Nisha\GUVI\Projects\Data\Diabetes_prediction.csv"
data=pd.read_csv(path)
data
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0              2  115.863387      56.410731      24.336736   94.385783
# 1              2   92.490122      70.615520      23.443591  138.652426
# 2              1   88.141469      63.262618      23.404364  149.358082
# 3              2  108.453101      67.793632      20.751580  108.751638
# 4              1  127.849443      94.725685      22.603078   25.269987
# ..           ...         ...            ...            ...         ...
# 995            1  103.496355      41.059401      24.930299   43.675978
# 996            1   60.714150      64.082842      24.689064  111.562745
# 997            0   97.597727      64.122312      22.140339  108.138552
# 998            0   66.775137      55.908797      24.885274  219.521484
# 999            0   87.647268      69.111593      25.621266  134.335745
#
#            BMI  DiabetesPedigreeFunction        Age  Diagnosis
# ...

# %%
print(f"data type of the csv file : {type(data)}")
# Out:
# data type of the csv file : <class 'pandas.core.frame.DataFrame'>

# %%
type(data.Pregnancies)
# Out:
# pandas.core.series.Series

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

x=[35,47,45,38,67]
y=[3,5,4,3,7]

plt.scatter(x,y)
plt.show()
